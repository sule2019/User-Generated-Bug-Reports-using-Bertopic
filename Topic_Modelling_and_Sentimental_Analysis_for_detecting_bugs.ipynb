# %% [markdown]
# <a href="https://colab.research.google.com/github/sule2019/User-Generated-Bug-Reports-using-Topic-Modelling/blob/main/Topic_Modelling_and_Sentimental_Analysis_for_detecting_bugs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade bertopic
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting bertopic
#   Downloading bertopic-0.14.1-py2.py3-none-any.whl (120 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 120.7/120.7 KB 2.9 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.20.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.22.4)
# Collecting hdbscan>=0.8.29
#   Downloading hdbscan-0.8.29.tar.gz (5.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.2/5.2 MB 38.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: tqdm>=4.41.1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (4.65.0)
# Requirement already satisfied: plotly>=4.7.0 in /usr/local/lib/python3.9/dist-packages (from bertopic) (5.5.0)
# Collecting sentence-transformers>=0.4.1
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 KB 10.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting umap-learn>=0.5.0
#   Downloading umap-learn-0.5.3.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.2/88.2 KB 9.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pandas>=1.1.5 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /usr/local/lib/python3.9/dist-packages (from bertopic) (1.2.1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.10.1)
# Requirement already satisfied: cython>=0.27 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (0.29.33)
# Requirement already satisfied: joblib>=1.0 in /usr/local/lib/python3.9/dist-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.9/dist-packages (from pandas>=1.1.5->bertopic) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: six in /usr/local/lib/python3.9/dist-packages (from plotly>=4.7.0->bertopic) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn>=0.22.2.post1->bertopic) (3.1.0)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.26.1-py3-none-any.whl (6.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 74.3 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (1.13.1+cu116)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (0.14.1+cu116)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence-transformers>=0.4.1->bertopic) (3.7)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.97-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 66.3 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.13.1-py3-none-any.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 19.4 MB/s eta 0:00:00
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.9/dist-packages (from umap-learn>=0.5.0->bertopic) (0.56.4)
# Collecting pynndescent>=0.5
#   Downloading pynndescent-0.5.8.tar.gz (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 65.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (23.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.25.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.5.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (3.9.0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (0.39.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.9/dist-packages (from numba>=0.49->umap-learn>=0.5.0->bertopic) (57.4.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence-transformers>=0.4.1->bertopic) (2022.6.2)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.6/7.6 MB 64.2 MB/s eta 0:00:00
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence-transformers>=0.4.1->bertopic) (8.1.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence-transformers>=0.4.1->bertopic) (8.4.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (1.26.14)
# Requirement already satisfied: chardet<5,>=3.0.2 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence-transformers>=0.4.1->bertopic) (2022.12.7)
# Building wheels for collected packages: hdbscan, sentence-transformers, umap-learn, pynndescent
#   Building wheel for hdbscan (pyproject.toml) ... done
#   Created wheel for hdbscan: filename=hdbscan-0.8.29-cp39-cp39-linux_x86_64.whl size=3582153 sha256=d1d1dc2ad790b030962c101eafaf1929ffadadae0fb9d1685d819398a9eb8abc
#   Stored in directory: /root/.cache/pip/wheels/05/6f/88/1a4c04276b98306f00217a1e300e6ba0252c6aa4f7616067ae
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=3b846eb8b028b4067a7397213dfc7a8c5af6aad2bf49590004da8033270848b7
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
#   Building wheel for umap-learn (setup.py) ... done
#   Created wheel for umap-learn: filename=umap_learn-0.5.3-py3-none-any.whl size=82829 sha256=c5688baa7eb369a3c76034748eb74781c5a2515856514aba0003d298eb6ba6d6
#   Stored in directory: /root/.cache/pip/wheels/f4/3e/1c/596d0a463d17475af648688443fa4846fef624d1390339e7e9
#   Building wheel for pynndescent (setup.py) ... done
#   Created wheel for pynndescent: filename=pynndescent-0.5.8-py3-none-any.whl size=55513 sha256=ab012c67ce8bdcfc809b6275df3877a12065f37f9c7db135c3b973289d3d5e14
#   Stored in directory: /root/.cache/pip/wheels/b9/89/cc/59ab91ef5b21dc2ab3635528d7d227f49dfc9169905dcb959d
# Successfully built hdbscan sentence-transformers umap-learn pynndescent
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, pynndescent, hdbscan, umap-learn, sentence-transformers, bertopic
# Successfully installed bertopic-0.14.1 hdbscan-0.8.29 huggingface-hub-0.13.1 pynndescent-0.5.8 sentence-transformers-2.2.2 sentencepiece-0.1.97 tokenizers-0.13.2 transformers-4.26.1 umap-learn-0.5.3

# %%
import pandas as pd
#Topic Modelling
from bertopic import BERTopic
from pandas.core.groupby.groupby import DataFrame
#Sentimental Analysis
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to /root/nltk_data...

# %%
facebook_dataset = pd.read_csv('Facebook.csv')
instagram_dataset = pd.read_csv('instagram.csv')

# %% [markdown]
# # Sentimental Analysis on the Total Dataset
# this is done to get an idea of the dataset by conducting and counting the sentiments for negative, positive and neutral on the entire dataset

# %%
sentiment_analyzer = SentimentIntensityAnalyzer()

def get_sentiment_score(text):
    score = sentiment_analyzer.polarity_scores(text)["compound"]
    if score >= 0.05:
        return "Positive"
    elif score <= -0.05:
        return "Negative"
    else:
        return "Neutral"

# %%
facebook_dataset["Sentiment"] = facebook_dataset["Review"].apply(get_sentiment_score)
instagram_dataset["Sentiment"] = instagram_dataset["Review"].apply(get_sentiment_score)

# %%
facebook_dataset
# Out:
#                      Name               Date  \
# 0              ROßIN TUDU  December 22, 2022
# 1             Dale Poston      March 5, 2023
# 2     MidnightStar Sparks      March 1, 2023
# 3            FryingRonald  February 21, 2023
# 4          marychel viray  February 14, 2023
# ...                   ...                ...
# 5235   Adelard Illhamsyah   January 25, 2023
# 5236      nancy grandovic   November 4, 2022
# 5237     Kathleen Antonio   January 12, 2023
# 5238       Shaurya Elijah    January 5, 2023
# 5239             Victor S  December 11, 2022
#
#                                                  Review  \
# 0     After the update on 11/23/22, I experienced bu...
# 1     The last couple of updates on this app have re...
# 2     This app used to be great, but now it's just b...
# 3     Facebook is a cool app to share posts and medi...
# 4     The video stretches to full screen when editin...
# ...                                                 ...
# 5235  This app deserve 1 star. Worst social media ap...
# 5236  Lately, facebook often can't load all pages an...
# 5237  The updates has so much bugs and crashes, i ca...
# 5238  Creating stories used to be fun here but not a...
# 5239  Facebook doesn't care about its users. There i...
#
#                                 Found Helpful  Stars  App Name Sentiment
# 0     57,702 people found this review helpful      4  facebook  Positive
# 1      3,823 people found this review helpful      1  facebook  Negative
# 2      9,633 people found this review helpful      2  facebook  Negative
# 3     14,835 people found this review helpful      4  facebook  Positive
# 4     12,512 people found this review helpful      1  facebook   Neutral
# ...                                       ...    ...       ...       ...
# 5235      56 people found this review helpful      1  facebook  Negative
# 5236       3 people found this review helpful      3  facebook  Negative
# 5237                                        0      1  facebook   Neutral
# 5238                                        0      3  facebook  Positive
# 5239       6 people found this review helpful      1  facebook  Negative
#
# [5240 rows x 7 columns]

# %%
instagram_dataset
# Out:
#                               Name               Date  \
# 0                       Harsh Deol      March 2, 2023
# 1                        Karthik B      March 3, 2023
# 2                         Mahati N  February 16, 2023
# 3     Devapriya Renjith Mampalathu  February 11, 2023
# 4                       Shamim Ara      March 4, 2023
# ...                            ...                ...
# 5515                        Dave L  December 29, 2022
# 5516                     Vivek Jha  February 15, 2023
# 5517                    Friday Uwu  December 21, 2022
# 5518                    D McDonagh  November 12, 2022
# 5519            Mažena Andrejevska  December 24, 2022
#
#                                                  Review  \
# 0     The number of new bugs with each update is atr...
# 1     It is an excellent app overall. The meta team ...
# 2     The number of new bugs with each update is atr...
# 3     So many glitches. Like so many!!! App closing ...
# 4     Everything is fine but from yesterday I'm faci...
# ...                                                 ...
# 5515  When you open the app, it will auto refresh be...
# 5516  So many glitches. When I log out the app and n...
# 5517  some messages are not received. I can only vie...
# 5518  Since it updated to loading only a few posts a...
# 5519  A lot of errors and bugs, stories don't record...
#
#                                 Found Helpful  Stars   App Name Sentiment
# 0      7,939 people found this review helpful      1  instagram  Negative
# 1      7,177 people found this review helpful      5  instagram  Positive
# 2     47,460 people found this review helpful      1  instagram  Negative
# 3     22,011 people found this review helpful      1  instagram  Negative
# 4      3,364 people found this review helpful      3  instagram  Positive
# ...                                       ...    ...        ...       ...
# 5515                                        0      2  instagram  Negative
# 5516                                        0      1  instagram  Negative
# 5517       1 person found this review helpful      3  instagram   Neutral
# 5518      72 people found this review helpful      2  instagram  Negative
# 5519                                        0      3  instagram  Negative
#
# [5520 rows x 7 columns]

# %%
#Facebook
fb_positive_sentiment = facebook_dataset[facebook_dataset['Sentiment'] == 'Positive'].reset_index()
fb_negative_sentiment = facebook_dataset[facebook_dataset['Sentiment'] == 'Negative'].reset_index()
fb_neutral_sentiment = facebook_dataset[facebook_dataset['Sentiment'] == 'Neutral'].reset_index()

#Instagram
insta_positive_sentiment = instagram_dataset[instagram_dataset['Sentiment'] == 'Positive'].reset_index()
insta_negative_sentiment = instagram_dataset[instagram_dataset['Sentiment'] == 'Negative'].reset_index()
insta_neutral_sentiment = instagram_dataset[instagram_dataset['Sentiment'] == 'Neutral'].reset_index()

# %%
print('Facebook Data Description')
print('Total datset: ',len(facebook_dataset))
print('No. of Postive Sentiments: ',len(fb_positive_sentiment))
print('No. of Negative Sentiments: ',len(fb_negative_sentiment))
print('No. of Neutral Sentiments: ',len(fb_neutral_sentiment))
print('\n')
print('Instagram Data Description')
print('Total datset: ',len(instagram_dataset))
print('No. of Postive Sentiments: ',len(insta_positive_sentiment))
print('No. of Negative Sentiments: ',len(insta_negative_sentiment))
print('No. of Neutral Sentiments: ',len(insta_neutral_sentiment))
# Out:
# Facebook Data Description
# Total datset:  5240
# No. of Postive Sentiments:  1905
# No. of Negative Sentiments:  2911
# No. of Neutral Sentiments:  424
#
#
# Instagram Data Description
# Total datset:  5520
# No. of Postive Sentiments:  2480
# No. of Negative Sentiments:  2701
# No. of Neutral Sentiments:  339

# %% [markdown]
# # Generate Bug reports
# Steps:
# 1. Prepare the dataset: filter dataset for bug related reviews
# 2. perform topic modelling
# 3. perform sentimental analysis
# 4. process the output

# %%
def GetBugs(dataset):

  #1. Preparing Dataset  
  #select all reviews in dataset where App Name(column) = app_name(ie. facebook)
  #app = [app_name]
  
  #make sure everything in review section is a string
  dataset['Review'] = dataset['Review'].astype(str)

  #Filter Reviews to retrieve reviews containing bugs reports keywords for accurate topic modelling
  bug_keywords = ["bug", "crash", "error", "issue",'Crash', 'Error', 'Bug', 'Glitch', 'Issue','Freeze', 'Shutdown', 'Hang', 'Black screen','Feature', 'Request', 'Functionality', 'Improvement', 'Enhancement','Usability', 'UI', 'UX', 'Navigation', 'Layout','Performance', 'Speed', 'Load Time', 'Responsiveness', 'Lag','Security', 'Privacy', 'Data', 'Encryption', 'Vulnerability','Hack', 'Breach','Login', 'Authentication', 'Password', 'Account', 'Signup','Compatibility', 'iOS', 'Android', 'Device', 'Version','Network', 'Connection', 'WiFi', 'Mobile data', 'Offline','Localization', 'Translation', 'Language', 'Region', 'Culture','UI', 'Design', 'Layout', 'Font', 'Color','Performance', 'Speed', 'Lag', 'Loading', 'Responsiveness','Battery', 'Drain', 'Power', 'Usage', 'Charge']
  dataset = dataset[dataset["Review"].str.contains("|".join(bug_keywords))].reset_index(drop=True)
  
  #Get information about dataset after filtering
  print("len of dataset after filtering: ",len(dataset))

  #2. Topic Modelling Using Bertopic
  topic_model = BERTopic(embedding_model='all-MiniLM-L6-v2')
  dataset = dataset['Review'].tolist()
  topics, probs = topic_model.fit_transform(dataset)

  #Combine topic and documents/Reviews into a single dataframe
  from pandas.core.groupby.groupby import DataFrame
  df = DataFrame({"Topic": topics, "Document": dataset})

  #Group reviews/documents by topic
  result = df.groupby('Topic')['Document'].agg(list).reset_index()

  # Initialize sentiment analyzer
  analyzer = SentimentIntensityAnalyzer()
  #3. Sentimental Analysis using Bertopic
  # Define a function to count sentiment for a list of reviews
  def count_sentiment(reviews):
      count_positive = 0
      count_negative = 0
      count_neutral = 0
      for review in reviews:
          sentiment_scores = analyzer.polarity_scores(review)
          if sentiment_scores['compound'] > 0.05:
              count_positive += 1
          elif sentiment_scores['compound'] < -0.05:
              count_negative += 1
          else:
              count_neutral += 1
      return count_positive, count_negative, count_neutral

  # Loop through the column of reviews in the dataframe and count sentiment for each row
  count_positive_list = []
  count_negative_list = []
  count_neutral_list = []
  for reviews in result['Document']:
      count_positive, count_negative, count_neutral = count_sentiment(reviews)
      count_positive_list.append(count_positive)
      count_negative_list.append(count_negative)
      count_neutral_list.append(count_neutral)

  # Append the results as new columns to the dataframe
  result['Count Positive'] = count_positive_list
  result['Count Negative'] = count_negative_list
  result['Count Neutral'] = count_neutral_list

  #4. Finalizing and processing the output
  #Get relevant information on the topics using the bertopic get_topic_info() method 
  topic_info = topic_model.get_topic_info()
  topic_info.drop('Topic', axis=1, inplace=True)

  #Add to the results dataframe
  final_results = pd.concat([result, topic_info], axis=1)

  #Rearrange the columns
  final_results = final_results[["Topic", "Name", "Document", "Count Positive", "Count Negative", "Count Neutral", "Count"]]

  #Return Final Results
  return final_results

# %%
facebook_output = GetBugs(facebook_dataset)
# Out:
# len of dataset after filtering:  1412
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
#Converting an editable output 
# %load_ext google.colab.data_table
#remove the document dolumn for visualization purposes
fb_final_output = facebook_output.drop('Document', axis=1)
#topic -1 usally contain irregular and irrelevant topics so it can be removed.
fb_final_output[1:]
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table
#     Topic                                        Name  Count Positive  \
# 1       0                       0_facebook_the_and_it              66
# 2       1                     1_video_videos_the_play              29
# 3       2                        2_and_the_update_app              29
# 4       3                           3_app_it_the_open              23
# 5       4                 4_account_login_my_facebook              21
# 6       5                5_account_my_facebook_hacked              13
# 7       6                    6_reels_comments_reel_it              16
# 8       7                 7_comments_comment_the_when              13
# 9       8                 8_marketplace_items_and_you              12
# 10      9                        9_log_in_error_login              10
# 11     10                 10_photos_featured_to_photo              15
# 12     11        11_notifications_notification_no_the              10
# 13     12             12_facebook_loading_session_app              13
# 14     13                   13_expired_session_log_in               9
# 15     14                      14_feed_posts_the_news               7
# 16     15                       15_music_story_it_bug              12
# 17     16             16_page_create_created_creating              10
# 18     17                17_profile_picture_change_it               9
# 19     18                            18_ad_the_ads_of               6
# 20     19            19_video_comment_comments_videos               7
# 21     20  20_code_authentication_authenticator_email               6
# 22     21                21_groups_group_post_members               6
# 23     22                 22_friend_friends_show_list              12
# 24     23                   23_dating_support_to_they               4
# 25     24        24_restricted_facebook_block_account               6
#
#     Count Negative  Count Neutral  Count
# 1               87             13    166
# 2               50             10     89
# 3               47             10     86
# 4               28             13     64
# 5               33              0     54
# 6               28              0     41
# 7               17              6     39
# 8               20              5     38
# 9               23              3     38
# 10              21              4     35
# 11              14              4     33
# 12              19              3     32
# 13              14              1     28
# 14              16              2     27
# 15              16              2     25
# 16               8              1     21
# 17               6              2     18
# 18               7              2     18
# 19              10              0     16
# 20               8              1     16
# 21               9              0     15
# 22               8              0     14
# 23               0              1     13
# 24               8              1     13
# 25               6              0     12

# %%
instagram_output = GetBugs(instagram_dataset)
# Out:
# len of dataset after filtering:  1990

# %%
#Converting an editable output 
# %load_ext google.colab.data_table
#remove the document dolumn for visualization purposes
insta_final_output = instagram_output.drop('Document', axis=1)
insta_final_output[1:]
# Out:
# The google.colab.data_table extension is already loaded. To reload it, use:
#   %reload_ext google.colab.data_table
#     Topic                                              Name  Count Positive  \
# 1       0                           0_photos_the_post_photo              69
# 2       1                             1_instagram_my_is_and              64
# 3       2                            2_instagram_app_of_the              39
# 4       3                            3_reels_option_not_the              25
# 5       4                             4_account_my_login_to              35
# 6       5                        5_photos_instagram_post_to              26
# 7       6                   6_account_my_instagram_password              20
# 8       7                       7_reels_instagram_option_my              21
# 9       8                            8_audio_reels_reel_the              22
# 10      9                           9_story_post_to_stories              26
# 11     10                              10_feed_posts_the_it              10
# 12     11            11_followers_following_follow_follower              21
# 13     12                      12_app_crashing_crashes_open              17
# 14     13                               13_reels_to_app_and              14
# 15     14                   14_messages_message_the_refresh               8
# 16     15                             15_bugs_app_that_they              13
# 17     16                          16_dark_mode_white_theme              12
# 18     17                          17_stories_story_app_the               9
# 19     18                       18_video_videos_post_upload              13
# 20     19                     19_story_stories_instagram_it              16
# 21     20                              20_tiktok_to_the_and               8
# 22     21                      21_reels_reel_instagram_like               5
# 23     22                     22_music_songs_song_instagram              10
# 24     23                      23_reply_messages_am_message               6
# 25     24  24_collaborator_invite_collaboration_collaborate               4
# 26     25                   25_notes_feature_reported_times               6
# 27     26                      26_notes_feature_account_but               8
# 28     27                                27_dms_dm_no_reply               5
# 29     28                               28_post_posts_as_it               5
# 30     29                             29_battery_app_it_but              11
#
#     Count Negative  Count Neutral  Count
# 1              124             15    208
# 2               56              4    124
# 3               63              2    104
# 4               51             13     89
# 5               52              1     88
# 6               37              3     66
# 7               31              2     53
# 8               29              2     52
# 9               22              5     49
# 10              15              2     43
# 11              26              5     41
# 12              16              3     40
# 13              18              2     37
# 14              21              1     36
# 15              17             10     35
# 16              19              2     34
# 17              15              4     31
# 18              19              3     31
# 19              13              2     28
# 20              10              0     26
# 21              14              0     22
# 22              12              1     18
# 23               7              0     17
# 24               7              3     16
# 25              11              0     15
# 26               7              2     15
# 27               4              2     14
# 28               8              0     13
# 29               7              1     13
# 30               2              0     13
